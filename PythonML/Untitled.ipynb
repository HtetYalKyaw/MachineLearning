# %%
# import matplotlib.pyplot as plt
# import numpy as np

# x = np.array([25,25,50,10])
# mylabels = ["apples","banana","dog", "chicken"]
# myexplode = [0.1,0,0,0]

# plt.pie(x, labels = mylabels,explode = myexplode ,startangle = 90,shadow = True)
# plt.legend(title = "Four Fruits:",loc = 'right')
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([5, 6, 1 , 10])

plt.bar(x,y, color = "r")
plt.show()
